# %% [markdown]
# Read a string and print the length

# %%
s = input("Enter a string: ")
print("Length of the string:", len(s))
# Out:
# Enter a string: raaghu
# Length of the string: 6

# %% [markdown]
# Reverse a string

# %%
s = input("Enter a string: ")
rev = ""

for ch in s:
    rev = ch + rev

print("Reversed string:", rev)
# Out:
# Enter a string: kumar
# Reversed string: ramuk

# %% [markdown]
# Palindrome

# %%
s = input("Enter a string: ")
rev = s[::-1]

if s == rev:
    print("Palindrome")
else:
    print("Not a Palindrome")
# Out:
# Enter a string: eye
# Palindrome

# %% [markdown]
# Convert lower case to upper case

# %%
s = input("Enter a string: ")
result = ""

for ch in s:
    if 'a' <= ch <= 'z':
        result += chr(ord(ch) - 32)
    else:
        result += ch

print("Uppercase string:", result)
# Out:
# Enter a string: raaghu
# Uppercase string: RAAGHU

# %% [markdown]
# Missing Numbers

# %%
numbers = list(map(int, input("Enter numbers: ").split()))

n = len(numbers) + 1
expected_sum = n * (n + 1) // 2
actual_sum = sum(numbers)

missing_number = expected_sum - actual_sum
print("Missing number:", missing_number)
# Out:
# Enter numbers: 6
# Missing number: -3

# %% [markdown]
# Replace negative numbers with zero

# %%
numbers = list(map(int, input("Enter numbers separated by space: ").split()))

for i in range(len(numbers)):
    if numbers[i] < 0:
        numbers[i] = 0

print("Updated list:", numbers)
# Out:
# Enter numbers separated by space: -2 -7 -9
# Updated list: [0, 0, 0]

# %% [markdown]
# Most frequent word in a sentence

# %%
s = input("Enter a sentence: ")
words = s.split()
freq = {}

for w in words:
    freq[w] = freq.get(w, 0) + 1

print("Most frequent word:", max(freq, key=freq.get))
# Out:
# Enter a sentence: raj is my friend and he is smart
# Most frequent word: is

# %% [markdown]
# Frequency of elements in a list

# %%
lst = list(map(int, input("Enter numbers: ").split()))
freq = {}

for num in lst:
    freq[num] = freq.get(num, 0) + 1

print(freq)
# Out:
# Enter numbers: 1221344334
# {1221344334: 1}

# %% [markdown]
# Count the vowels in each word of a sentence

# %%
sentence = input("Enter a sentence: ")

vowels = "aeiouAEIOU"
words = sentence.split()

for word in words:
    count = 0
    for ch in word:
        if ch in vowels:
            count += 1
    print(word, ":", count)
# Out:
# Enter a sentence: wealth
# wealth : 2
