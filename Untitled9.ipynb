# %%
word="raaghu"
print(word[0])
print(word[1])
print(word[-1])
print(word[-2])
# Out:
# r
# a
# u
# h

# %%
text="raaghu"
print(text[0:4])
# Out:
# raag

# %%
name="python"
print(len(name))
# Out:
# 6

# %%
"raaghu".upper()
# Out:
# 'RAAGHU'

# %%
"RAAGHU".lower()
# Out:
# 'raaghu'

# %%
name="raaghavendra"
print(name.strip())
# Out:
# raaghavendra

# %%
email="raaghu2gmail.com"
print("u" in email)
# Out:
# True

# %%
sentence="taj is very beautiful"
words=sentence.split()
print(words)
# Out:
# ['taj', 'is', 'very', 'beautiful']

# %%
words=["python","is","fun"]
print("".join(words))
# Out:
# pythonisfun

# %%
first="hello"
second="world"
print(first+""+second)
# Out:
# helloworld

# %%
name="preetham"
age=21
print(f"my name is {name} and my age is {age}")
# Out:
# my name is preetham and my age is 21

# %%
text="banana"
print(text.count("a"))
# Out:
# 3

# %%
url="https://example.com"
url.startswith("httk")
# Out:
# False

# %%
file="data.csv"
file.endswith(".csv")
# Out:
# True
