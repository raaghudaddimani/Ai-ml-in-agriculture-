# %%
fruits=["apple","banana","mango"]
print(fruits[0])
# Out:
# apple

# %%
coordinates=(10,20)
print(coordinates[1])
# Out:
# 20

# %%
numbers={1,2,3,3,2}
print(numbers)
# Out:
# {1, 2, 3}

# %%
marks={"maths":85,
"science":90}
marks["english"]=88
print(marks)
# Out:
# {'maths': 85, 'science': 90, 'english': 88}
