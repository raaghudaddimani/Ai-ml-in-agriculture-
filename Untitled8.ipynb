# %%
thislist=["apple","banana","cherry"]
print(thislist[-1])
# Out:
# cherry

# %%
thislist=("apple","banana","cherry","orange","kiwi","mango","melon")
print(thislist[2:5])
# Out:
# ('cherry', 'orange', 'kiwi')

# %%
thislist=("rice","wheat","bajra","maize","sorghum","ragi")
print(thislist[:5])
# Out:
# ('rice', 'wheat', 'bajra', 'maize', 'sorghum')

# %%
thislist=("rice","wheat","bajra","maize","sorghum","ragi")
print(thislist[3:])
# Out:
# ('maize', 'sorghum', 'ragi')

# %%
thislist=["rice","wheat","bajra","maize","sorghum","ragi"]
print(thislist[-5:-1])
# Out:
# ['wheat', 'bajra', 'maize', 'sorghum']

# %%
thislist=["apple","banana","cherry"]
thislist[1]="blackcurrent"
print(thislist)
# Out:
# ['apple', 'blackcurrent', 'cherry']

# %%
thislist=["apple","banana","cherry"]
thislist[1:2]=["blackcurrent","watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrent', 'watermelon', 'cherry']

# %%
thislist=["apple","banana","cherry"]
thislist[0:2]=["blackcurrent","watermelon"]
print(thislist)
# Out:
# ['blackcurrent', 'watermelon', 'cherry']

# %%
thislist=["apple","banana","cherry"]
thislist[1:2]=["blackcurrent"]
print(thislist)
# Out:
# ['apple', 'blackcurrent', 'cherry']

# %%
thislist=["rice","wheat","bajra","maize"]
thislist.insert(2,"sorghum")
print(thislist)
# Out:
# ['rice', 'wheat', 'sorghum', 'bajra', 'maize']

# %%
thislist=["apple","banana","cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist=["apple","banana","cherry"]
thiscrop=["rice","wheat","bajra","maize"]
thislist=thislist+thiscrop
print(thislist)
a=20
b=30
c=a+b
print(c)
# Out:
# ['apple', 'banana', 'cherry', 'rice', 'wheat', 'bajra', 'maize']
# 50

# %%
thislist.remove("40")
print(thislist)
# Out:
# ['20', '30', '50']

# %%
thislist=["rice","wheat","bajra","maize","maize"]
thislist.remove("maize")
print(thislist)
# Out:
# ['rice', 'wheat', 'bajra', 'maize']

# %%
thislist=["rice","wheat","bajra","maize","maize"]
del thislist[2]
print(thislist)
# Out:
# ['rice', 'wheat', 'maize', 'maize']

# %%
thislistt=["rice","wheat","bajra","maize","maize"]
del thislist[4]
print(thislist)
# Out:
# ['rice', 'wheat', 'bajra', 'maize']

# %%
thislist=["rice","wheat","bajra","maize","maize"]
thislist.clear()
print(thislist)
# Out:
# []
