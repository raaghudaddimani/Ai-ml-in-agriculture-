# %%
import numpy as np
cricket_score=[10,14,16,100]
median_score=np.median(cricket_score)
print(f"median:{median_score}")
# Out:
# median:15.0

# %%
from statistics import mode
votes=[1,2,2,2,3,3,4,4,5,6,7,7,7,9,7]
most_common=mode(votes)
print(most_common)
# Out:
# 7

# %%
import numpy as np
tight_data=[60,70,80]
spread_data=[20,70,120]
print("tight std:",np.std(tight_data))
print("spread std:",np.std(spread_data))
# Out:
# tight std: 8.16496580927726
# spread std: 40.824829046386306

# %%
import random
for i in range(5):
    prediction=random.choice(["spam","not spam"])
    print(f"email{i+1}:{prediction}")
# Out:
# email1:not spam
# email2:not spam
# email3:spam
# email4:not spam
# email5:not spam

# %%
import random
samples=[random.randint(1,6)
for _ in range(10)]
print("sample rolls:",samples)
print("sample mean:",sum(samples)/len(samples))
# Out:
# sample rolls: [2, 2, 3, 2, 4, 6, 4, 1, 2, 5]
# sample mean: 3.1
