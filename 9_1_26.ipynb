# %%
import numpy as np
a=np.array([1,7,8,9])
b=np.array([2,5,6,4])
print(a+b)
# Out:
# [ 3 12 14 13]

# %%
#matrices#
import numpy as np
x=np.array([[1,2,3],[4,5,6]])
print(x)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
#dot product#
import numpy as np
np.dot([3,4],[5,6])
# Out:
# np.int64(39)

# %%
#probability#
import random
outcomes=["spam","not spam"]
print(random.choice(outcomes))
# Out:
# spam

# %%
#statistics#
import numpy as np
scores=[99,88,86,97,93]
print(np.mean(scores))
# Out:
# 92.6

# %%
w=7
ir=0.2
for i in range(3):
  w=w-ir*2*w
  print(w)
# Out:
# 4.199999999999999
# 2.5199999999999996
# 1.5119999999999998

# %%
file=open("attendance.txt","r")
file.write("priyanshu\n raaghu\n ashwini\n hanumanthi\n ashwini")
file.close
file=open("attendance.txt","r")
print(file.read())
file.close
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3738631263.py in <cell line: 0>()
# ----> 1 file=open("attendance.txt","r")
#       2 file.write("priyanshu\n raaghu\n ashwini\n hanumanthi\n ashwini")
#       3 file.close
#       4 file=open("attendance.txt","r")
#       5 print(file.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'attendance.txt'
