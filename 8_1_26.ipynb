# %%
farm_data=[
    [1,"rice",45],
    [2,"wheat",30],
    [3,"maize",60]
]
print(farm_data)
print(farm_data[0])
print(farm_data[0][1])
# Out:
# [[1, 'rice', 45], [2, 'wheat', 30], [3, 'maize', 60]]
# [1, 'rice', 45]
# rice

# %%
yield_data=[
    ["rice",3200],
    ["wheat",2800],
    ["maize",4000]
]
for crop in yield_data:
  print(crop[0],"yield:",crop[1],"kg/hectare")
# Out:
# rice yield: 3200 kg/hectare
# wheat yield: 2800 kg/hectare
# maize yield: 4000 kg/hectare

# %%
crop_plan=[
    ["kharif",["rice"],["maize"]],
    ["rabi",["gram"],["wheat"]],
    ["zaid",["vegetables"]]
]
print(crop_plan[0][2])
# Out:
# ['maize']

# %%
#daily farm expenses
expenses=[
    ["day1",[1200,500,300]],
    ["day2",[1500,400,600]],
    ["day3",[1000,700,200]]
]
print(expenses[0])
# Out:
# ['day1', [1200, 500, 300]]

# %%
expenses=[
    ["day1",[1200,500,300]],
    ["day2",[1500,400,600]],
    ["day3",[1000,700,200]]
    ]
print(expenses[0])
for day in expenses:
 print(day[0],"total:",sum(day[1]))
# Out:
# ['day1', [1200, 500, 300]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1863201460.py in <cell line: 0>()
#       6 print(expenses[0])
#       7 for day in expenses:
# ----> 8  print(day[0],"total:",sum(day[1]))
#
# TypeError: 'list' object is not callable

# %%
def expenses_made():
  expenses=[]
  number_of_days=int(input("Enter the number of days:"))
  for i in range(number_of_days):
    day_name=input(f"enter the day name:")
    seed_cost=int(input("enter the seed cost:"))
    fertilizer_cost=int(input("enter the fertilizer cost:"))
    labour_cost=int(input("enter the labour cost:"))

    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses

  total_expediture=expenses_made()
  print("daily expenses:")
  def expenses_made():
  expenses=[]
  number_of_days=int(input("Enter the number of days:"))
  for i in range(number_of_days):
    day_name=input(f"enter the day name:")
    seed_cost=int(input("enter the seed cost:"))
    fertilizer_cost=int(input("enter the fertilizer cost:"))
    labour_cost=int(input("enter the labour cost:"))

    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses

  total_expediture=expenses_made()
  print("daily expenses:")
  for expenditure in total_expenditure:
    print(expenditure[0],"expenses are:",expenditure[1])

expenses_made()
def expenses_made():
  expenses=[]
  number_of_days=int(input("Enter the number of days:"))
  for i in range(number_of_days):
    day_name=input(f"enter the day name:")
    seed_cost=int(input("enter the seed cost:"))
    fertilizer_cost=int(input("enter the fertilizer cost:"))
    labour_cost=int(input("enter the labour cost:"))

    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses

  total_expediture=expenses_made()
  print("daily expenses:")
  overall_total=0
  for expenditure in total_expenditure:
   daily_total=sum(expenditure[1])
   print(expenditure[0],"expenses are,expenditure[1],"total for day:,"daily_total")
   overall_total+=daily_total
   print("total expenses for all days:",overall_total)
expenses_made()
# Out:
#   File "/tmp/ipython-input-3714856716.py", line 16
#     expenses=[]
#     ^
# IndentationError: expected an indented block after function definition on line 15

# %%
def expenses_made():
  expenses=[]
  number_of_days=int(input("Enter the number of days:"))
  for i in range(number_of_days):
    day_name=input(f"enter the day name:")
    seed_cost=int(input("enter the seed cost:"))
    fertilizer_cost=int(input("enter the fertilizer cost:"))
    labour_cost=int(input("enter the labour cost:"))

    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses

total_expenditure=expenses_made()
print("daily expenses:")
overall_total=0
for expenditure in total_expenditure:
   daily_total=builtins.sum(expenditure[1])
   print(expenditure[0],"expenses are",expenditure[1],"total for day:",daily_total)
   overall_total+=daily_total
print("total expenses for all days:",overall_total)
# Out:
# Enter the number of days:2
# enter the day name:sahana
# enter the seed cost:2300
# enter the fertilizer cost:3000
# enter the labour cost:4500
# enter the day name:maha
# enter the seed cost:2000
# enter the fertilizer cost:2500
# enter the labour cost:3200
# daily expenses:
# sahana expenses are [2300, 3000, 4500] total for day: 9800
# maha expenses are [2000, 2500, 3200] total for day: 7700
# total expenses for all days: 17500

# %%
thistuple=("apple","banana","cherry","apple","cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')

# %%
thistuple=("apple","banana","cherry")
print(len(thistuple))
# Out:
# 3

# %%
thistuple=("apple",)
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
fruits=("apple","banana","cherry","guava","orange")
print(fruits)
(green,yellow,*red)=fruits
print(green)
print(yellow)
print(red)
# Out:
# ('apple', 'banana', 'cherry', 'guava', 'orange')
# apple
# banana
# ['cherry', 'guava', 'orange']
