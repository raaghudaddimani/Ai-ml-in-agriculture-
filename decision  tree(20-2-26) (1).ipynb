# %%
#Decision Trees for classification#
import pandas as pd
# Crop health dataset
data = {
 "Yellow_Leaves": [1, 1, 0, 0, 1, 0, 1, 0],
 "Spots_Present": [1, 0, 0, 0, 1, 0, 0, 0],
 "Disease": ["Fungal", "Nutrient", "Healthy",
 "Healthy", "Fungal", "Healthy",
 "Nutrient", "Healthy"]
}
df = pd.DataFrame(data)
df
# Out:
#    Yellow_Leaves  Spots_Present   Disease
# 0              1              1    Fungal
# 1              1              0  Nutrient
# 2              0              0   Healthy
# 3              0              0   Healthy
# 4              1              1    Fungal
# 5              0              0   Healthy
# 6              1              0  Nutrient
# 7              0              0   Healthy

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Define features (X) and target (y)
X = df[['Yellow_Leaves', 'Spots_Present']]
y = df['Disease']

# Initialize and train the Decision Tree Classifier
model = DecisionTreeClassifier()
model.fit(X, y)

# Visualizing the decision tree#
plt.figure(figsize=(12,8))
plot_tree(model,
 feature_names=X.columns,
 class_names=model.classes_,
 filled=True,
 rounded=True)
plt.title("Decision Tree for Crop Disease Prediction")
plt.show()
