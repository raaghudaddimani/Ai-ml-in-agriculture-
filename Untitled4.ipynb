# %%
rnf=float(input("enter the rnf in mm"))
if(rnf>25):
  print("suitable for crop growth")
else:
  print("not suitable for crop growth")
# Out:
# enter the temp in degree celcius100
# suitable for crop growth
