# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import os

# --- 1. Data Loading (Conceptual) ---
# In a real scenario, you would have a dataset of images, for example,
# organized into subdirectories by disease type (e.g., 'healthy', 'blight', 'rust').
# Let's simulate some paths for demonstration.

data_dir = 'path/to/your/plant_disease_dataset' # Replace with your dataset path
image_size = (128, 128)
batch_size = 32

# Using ImageDataGenerator for loading and augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2 # 20% for validation
)

# A dummy directory creation for demonstration purposes if `data_dir` doesn't exist
# In a real scenario, you'd ensure your dataset is properly structured.
if not os.path.exists(data_dir):
    print(f"Warning: '{data_dir}' not found. Creating dummy structure for demonstration.")
    os.makedirs(os.path.join(data_dir, 'train', 'healthy'), exist_ok=True)
    os.makedirs(os.path.join(data_dir, 'train', 'diseased'), exist_ok=True)
    os.makedirs(os.path.join(data_dir, 'validation', 'healthy'), exist_ok=True)
    os.makedirs(os.path.join(data_dir, 'validation', 'diseased'), exist_ok=True)


train_generator = train_datagen.flow_from_directory(
    os.path.join(data_dir, 'train'),
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    os.path.join(data_dir, 'train'), # Using train data for validation subset
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Get the number of classes (disease types)
num_classes = len(train_generator.class_indices)
print(f"Detected {num_classes} classes: {train_generator.class_indices}")

# --- 2. Model Building (Simple CNN) ---
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(image_size[0], image_size[1], 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax') # Output layer with num_classes neurons
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# --- 3. Model Training (Conceptual) ---
# This step requires actual data and can take a long time.
# We'll skip actual training here and just show the command.

print("\n--- Starting conceptual model training ---")
# history = model.fit(
#     train_generator,
#     steps_per_epoch=train_generator.samples // batch_size,
#     epochs=10, # You would train for more epochs
#     validation_data=validation_generator,
#     validation_steps=validation_generator.samples // batch_size
# )

print("Conceptual training complete. (Actual training was commented out)")

# --- 4. Prediction (Conceptual) ---
# After training, you would load a new image and make a prediction.

def predict_plant_disease(image_path, model, class_indices, image_size):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=image_size)
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) # Create a batch
    img_array /= 255.0 # Rescale the image

    predictions = model.predict(img_array)
    predicted_class_index = np.argmax(predictions[0])

    # Invert class_indices to get class name from index
    labels = dict((v, k) for k, v in class_indices.items())
    predicted_class_name = labels[predicted_class_index]

    confidence = np.max(predictions[0])

    return predicted_class_name, confidence

# Example usage (will not run without a trained model and an actual image file):
# if num_classes > 0:
#     dummy_image_path = 'path/to/a/new/plant_image.jpg'
#     # Make sure to replace 'path/to/a/new/plant_image.jpg' with an actual image file
#     # and ensure the model has been trained before calling this.
#     if os.path.exists(dummy_image_path):
#         predicted_disease, conf = predict_plant_disease(dummy_image_path, model, train_generator.class_indices, image_size)
#         print(f"\nPredicted disease: {predicted_disease} with confidence: {conf:.2f}")
#     else:
#         print(f"\nCannot make prediction: '{dummy_image_path}' not found.")
# else:
#     print("\nCannot make prediction: No classes detected from the dummy data setup.")

print("\nPrediction function defined. To use it, you'd need a trained model and a new image file.")
# Out:
# ...
# Found 0 images belonging to 2 classes.
# Found 0 images belonging to 2 classes.
# Detected 2 classes: {'diseased': 0, 'healthy': 1}
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ...

# %% [markdown]
# ### Conceptual Code for Plant Disease Identification
#
# This example outlines the typical steps involved:
# 1.  **Data Loading:** Preparing image data for training and testing.
# 2.  **Model Building:** Creating a Convolutional Neural Network (CNN).
# 3.  **Model Training:** Teaching the model to identify diseases.
# 4.  **Prediction:** Using the trained model to classify new images.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import os

# --- 1. Data Loading (Conceptual) ---
# In a real scenario, you would have a dataset of images, for example,
# organized into subdirectories by disease type (e.g., 'healthy', 'blight', 'rust').
# Let's simulate some paths for demonstration.

data_dir = 'path/to/your/plant_disease_dataset' # Replace with your dataset path
image_size = (128, 128)
batch_size = 32

# Using ImageDataGenerator for loading and augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2 # 20% for validation
)

# A dummy directory creation for demonstration purposes if `data_dir` doesn't exist
# In a real scenario, you'd ensure your dataset is properly structured.
if not os.path.exists(data_dir):
    print(f"Warning: '{data_dir}' not found. Creating dummy structure for demonstration.")
    os.makedirs(os.path.join(data_dir, 'train', 'healthy'), exist_ok=True)
    os.makedirs(os.path.join(data_dir, 'train', 'diseased'), exist_ok=True)
    os.makedirs(os.path.join(data_dir, 'validation', 'healthy'), exist_ok=True)
    os.makedirs(os.path.join(data_dir, 'validation', 'diseased'), exist_ok=True)


train_generator = train_datagen.flow_from_directory(
    os.path.join(data_dir, 'train'),
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    os.path.join(data_dir, 'train'), # Using train data for validation subset
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Get the number of classes (disease types)
num_classes = len(train_generator.class_indices)
print(f"Detected {num_classes} classes: {train_generator.class_indices}")

# --- 2. Model Building (Simple CNN) ---
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(image_size[0], image_size[1], 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax') # Output layer with num_classes neurons
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# --- 3. Model Training (Conceptual) ---
# This step requires actual data and can take a long time.
# We'll skip actual training here and just show the command.

print("\n--- Starting conceptual model training ---")
# history = model.fit(
#     train_generator,
#     steps_per_epoch=train_generator.samples // batch_size,
#     epochs=10, # You would train for more epochs
#     validation_data=validation_generator,
#     validation_steps=validation_generator.samples // batch_size
# )

print("Conceptual training complete. (Actual training was commented out)")

# --- 4. Prediction (Conceptual) ---
# After training, you would load a new image and make a prediction.

def predict_plant_disease(image_path, model, class_indices, image_size):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=image_size)
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) # Create a batch
    img_array /= 255.0 # Rescale the image

    predictions = model.predict(img_array)
    predicted_class_index = np.argmax(predictions[0])

    # Invert class_indices to get class name from index
    labels = dict((v, k) for k, v in class_indices.items())
    predicted_class_name = labels[predicted_class_index]

    confidence = np.max(predictions[0])

    return predicted_class_name, confidence

# Example usage (will not run without a trained model and an actual image file):
# if num_classes > 0:
#     dummy_image_path = 'path/to/a/new/plant_image.jpg'
#     # Make sure to replace 'path/to/a/new/plant_image.jpg' with an actual image file
#     # and ensure the model has been trained before calling this.
#     if os.path.exists(dummy_image_path):
#         predicted_disease, conf = predict_plant_disease(dummy_image_path, model, train_generator.class_indices, image_size)
#         print(f"\nPredicted disease: {predicted_disease} with confidence: {conf:.2f}")
#     else:
#         print(f"\nCannot make prediction: '{dummy_image_path}' not found.")
# else:
#     print("\nCannot make prediction: No classes detected from the dummy data setup.")

print("\nPrediction function defined. To use it, you'd need a trained model and a new image file.")
