# %%
for i in range(2):
 for j in range (3):
   print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2

# %%
for i in range(3):
  for j in range(2):
    print("*",end =" ")
  print()
# Out:
# * *
# * *
# * *

# %%
rows=int(input("enterrows"))
cols=int(input("enter coloumns"))
for i in range(rows):
  for j in range(cols):
    print("#",end="")
  print()
# Out:
# enterrows2
# enter coloumns4
# ####
# ####

# %%
for i in range(3):
  j=0
  while j<2:
    print(i,j)
    j+=1
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1
